# %%
# Auxiliary import and Functions

import numpy as np
import matplotlib.pyplot as plt 
plt.rcParams.update({"figure.dpi":120})

import sys
sys.path.append("/home/faoli/programs/lsst/TJPCov/")


def cov2corr(cov):
    """
    Convert a covariance matrix into a correlation matrix
    input:
        cov: numpy.array with dim:(N,N)
    returns:
        corr: numpy.array with dim:(N,N)
    """
    sig = np.sqrt(cov.diagonal())
    return cov/np.outer(sig, sig)

# %% [markdown]
# ## Input file:
# check the appendix of this notebook for the contents of .yaml file

# %%
homepath = '/home/faoli/programs/lsst/TJPCov/' # Edit with your TJPCov path. e.g.: '/home/faoli/programs/lsst/TJPCov/'
# %cd {homepath}
config_yml = f"{homepath}/tests/data/conf_covariance_gaussian_fsky_fourier_2.yaml"
# Out:
# /home/faoli/programs/lsst/TJPCov

# %% [markdown]
# ## Using TJPCov Gaussian Fsky
#
# 1. Import and create the object:

# %%
from tjpcov.covariance_calculator import CovarianceCalculator
cc = CovarianceCalculator(config_yml)

# %% [markdown]
# 2. Get your covariance (This should not take a long time)

# %%
# %%time 
cov = cc.get_covariance()
# Out:
# Computing independent covariance blocks
# Rank None: ('lens0', 'lens0'), ('lens0', 'lens0')
# /home/faoli/anaconda3/envs/tjpcov/lib/python3.7/site-packages/sacc/sacc.py:370: UserWarning: Empty index selected - maybe you should check the tracer order?
#   warnings.warn("Empty index selected - maybe you "
# /home/faoli/programs/lsst/TJPCov/tjpcov/covariance_builder.py:846: UserWarning: Missing n_ell_coupled info for some tracers in the sacc file. You will have to pass it withthe cache
#   "Missing n_ell_coupled info for some tracers in "
# Rank None: ('lens0', 'lens0'), ('lens1', 'lens1')
# Rank None: ('lens0', 'lens0'), ('lens2', 'lens2')
# Rank None: ('lens0', 'lens0'), ('lens3', 'lens3')
# Rank None: ('lens0', 'lens0'), ('lens4', 'lens4')
# Rank None: ('lens0', 'lens0'), ('lens0', 'src0')
# Rank None: ('lens0', 'lens0'), ('lens0', 'src1')
# Rank None: ('lens0', 'lens0'), ('lens0', 'src2')
# Rank None: ('lens0', 'lens0'), ('lens0', 'src3')
# Rank None: ('lens0', 'lens0'), ('lens1', 'src0')
# Rank None: ('lens0', 'lens0'), ('lens1', 'src1')
# Rank None: ('lens0', 'lens0'), ('lens1', 'src2')
# Rank None: ('lens0', 'lens0'), ('lens1', 'src3')
# Rank None: ('lens0', 'lens0'), ('lens2', 'src0')
# Rank None: ('lens0', 'lens0'), ('lens2', 'src1')
# Rank None: ('lens0', 'lens0'), ('lens2', 'src2')
# Rank None: ('lens0', 'lens0'), ('lens2', 'src3')
# Rank None: ('lens0', 'lens0'), ('lens3', 'src0')
# Rank None: ('lens0', 'lens0'), ('lens3', 'src1')
# Rank None: ('lens0', 'lens0'), ('lens3', 'src2')
# Rank None: ('lens0', 'lens0'), ('lens3', 'src3')
# Rank None: ('lens0', 'lens0'), ('lens4', 'src0')
# Rank None: ('lens0', 'lens0'), ('lens4', 'src1')
# Rank None: ('lens0', 'lens0'), ('lens4', 'src2')
# Rank None: ('lens0', 'lens0'), ('lens4', 'src3')
# Rank None: ('lens0', 'lens0'), ('src0', 'src0')
# Rank None: ('lens0', 'lens0'), ('src0', 'src1')
# Rank None: ('lens0', 'lens0'), ('src0', 'src2')
# Rank None: ('lens0', 'lens0'), ('src0', 'src3')
# Rank None: ('lens0', 'lens0'), ('src1', 'src1')
# Rank None: ('lens0', 'lens0'), ('src1', 'src2')
# Rank None: ('lens0', 'lens0'), ('src1', 'src3')
# Rank None: ('lens0', 'lens0'), ('src2', 'src2')
# Rank None: ('lens0', 'lens0'), ('src2', 'src3')
# Rank None: ('lens0', 'lens0'), ('src3', 'src3')
# Rank None: ('lens1', 'lens1'), ('lens1', 'lens1')
# Rank None: ('lens1', 'lens1'), ('lens2', 'lens2')
# Rank None: ('lens1', 'lens1'), ('lens3', 'lens3')
# Rank None: ('lens1', 'lens1'), ('lens4', 'lens4')
# Rank None: ('lens1', 'lens1'), ('lens0', 'src0')
# Rank None: ('lens1', 'lens1'), ('lens0', 'src1')
# Rank None: ('lens1', 'lens1'), ('lens0', 'src2')
# Rank None: ('lens1', 'lens1'), ('lens0', 'src3')
# Rank None: ('lens1', 'lens1'), ('lens1', 'src0')
# Rank None: ('lens1', 'lens1'), ('lens1', 'src1')
# Rank None: ('lens1', 'lens1'), ('lens1', 'src2')
# Rank None: ('lens1', 'lens1'), ('lens1', 'src3')
# Rank None: ('lens1', 'lens1'), ('lens2', 'src0')
# Rank None: ('lens1', 'lens1'), ('lens2', 'src1')
# Rank None: ('lens1', 'lens1'), ('lens2', 'src2')
# Rank None: ('lens1', 'lens1'), ('lens2', 'src3')
# Rank None: ('lens1', 'lens1'), ('lens3', 'src0')
# Rank None: ('lens1', 'lens1'), ('lens3', 'src1')
# Rank None: ('lens1', 'lens1'), ('lens3', 'src2')
# Rank None: ('lens1', 'lens1'), ('lens3', 'src3')
# Rank None: ('lens1', 'lens1'), ('lens4', 'src0')
# Rank None: ('lens1', 'lens1'), ('lens4', 'src1')
# Rank None: ('lens1', 'lens1'), ('lens4', 'src2')
# Rank None: ('lens1', 'lens1'), ('lens4', 'src3')
# Rank None: ('lens1', 'lens1'), ('src0', 'src0')
# Rank None: ('lens1', 'lens1'), ('src0', 'src1')
# Rank None: ('lens1', 'lens1'), ('src0', 'src2')
# Rank None: ('lens1', 'lens1'), ('src0', 'src3')
# Rank None: ('lens1', 'lens1'), ('src1', 'src1')
# Rank None: ('lens1', 'lens1'), ('src1', 'src2')
# Rank None: ('lens1', 'lens1'), ('src1', 'src3')
# Rank None: ('lens1', 'lens1'), ('src2', 'src2')
# Rank None: ('lens1', 'lens1'), ('src2', 'src3')
# Rank None: ('lens1', 'lens1'), ('src3', 'src3')
# Rank None: ('lens2', 'lens2'), ('lens2', 'lens2')
# Rank None: ('lens2', 'lens2'), ('lens3', 'lens3')
# Rank None: ('lens2', 'lens2'), ('lens4', 'lens4')
# Rank None: ('lens2', 'lens2'), ('lens0', 'src0')
# Rank None: ('lens2', 'lens2'), ('lens0', 'src1')
# Rank None: ('lens2', 'lens2'), ('lens0', 'src2')
# Rank None: ('lens2', 'lens2'), ('lens0', 'src3')
# Rank None: ('lens2', 'lens2'), ('lens1', 'src0')
# Rank None: ('lens2', 'lens2'), ('lens1', 'src1')
# Rank None: ('lens2', 'lens2'), ('lens1', 'src2')
# Rank None: ('lens2', 'lens2'), ('lens1', 'src3')
# Rank None: ('lens2', 'lens2'), ('lens2', 'src0')
# Rank None: ('lens2', 'lens2'), ('lens2', 'src1')
# Rank None: ('lens2', 'lens2'), ('lens2', 'src2')
# Rank None: ('lens2', 'lens2'), ('lens2', 'src3')
# Rank None: ('lens2', 'lens2'), ('lens3', 'src0')
# Rank None: ('lens2', 'lens2'), ('lens3', 'src1')
# Rank None: ('lens2', 'lens2'), ('lens3', 'src2')
# Rank None: ('lens2', 'lens2'), ('lens3', 'src3')
# Rank None: ('lens2', 'lens2'), ('lens4', 'src0')
# Rank None: ('lens2', 'lens2'), ('lens4', 'src1')
# Rank None: ('lens2', 'lens2'), ('lens4', 'src2')
# Rank None: ('lens2', 'lens2'), ('lens4', 'src3')
# Rank None: ('lens2', 'lens2'), ('src0', 'src0')
# Rank None: ('lens2', 'lens2'), ('src0', 'src1')
# Rank None: ('lens2', 'lens2'), ('src0', 'src2')
# Rank None: ('lens2', 'lens2'), ('src0', 'src3')
# Rank None: ('lens2', 'lens2'), ('src1', 'src1')
# Rank None: ('lens2', 'lens2'), ('src1', 'src2')
# Rank None: ('lens2', 'lens2'), ('src1', 'src3')
# Rank None: ('lens2', 'lens2'), ('src2', 'src2')
# Rank None: ('lens2', 'lens2'), ('src2', 'src3')
# Rank None: ('lens2', 'lens2'), ('src3', 'src3')
# Rank None: ('lens3', 'lens3'), ('lens3', 'lens3')
# Rank None: ('lens3', 'lens3'), ('lens4', 'lens4')
# Rank None: ('lens3', 'lens3'), ('lens0', 'src0')
# Rank None: ('lens3', 'lens3'), ('lens0', 'src1')
# Rank None: ('lens3', 'lens3'), ('lens0', 'src2')
# Rank None: ('lens3', 'lens3'), ('lens0', 'src3')
# Rank None: ('lens3', 'lens3'), ('lens1', 'src0')
# Rank None: ('lens3', 'lens3'), ('lens1', 'src1')
# Rank None: ('lens3', 'lens3'), ('lens1', 'src2')
# Rank None: ('lens3', 'lens3'), ('lens1', 'src3')
# Rank None: ('lens3', 'lens3'), ('lens2', 'src0')
# Rank None: ('lens3', 'lens3'), ('lens2', 'src1')
# Rank None: ('lens3', 'lens3'), ('lens2', 'src2')
# Rank None: ('lens3', 'lens3'), ('lens2', 'src3')
# Rank None: ('lens3', 'lens3'), ('lens3', 'src0')
# Rank None: ('lens3', 'lens3'), ('lens3', 'src1')
# Rank None: ('lens3', 'lens3'), ('lens3', 'src2')
# Rank None: ('lens3', 'lens3'), ('lens3', 'src3')
# Rank None: ('lens3', 'lens3'), ('lens4', 'src0')
# Rank None: ('lens3', 'lens3'), ('lens4', 'src1')
# Rank None: ('lens3', 'lens3'), ('lens4', 'src2')
# Rank None: ('lens3', 'lens3'), ('lens4', 'src3')
# Rank None: ('lens3', 'lens3'), ('src0', 'src0')
# Rank None: ('lens3', 'lens3'), ('src0', 'src1')
# Rank None: ('lens3', 'lens3'), ('src0', 'src2')
# Rank None: ('lens3', 'lens3'), ('src0', 'src3')
# Rank None: ('lens3', 'lens3'), ('src1', 'src1')
# Rank None: ('lens3', 'lens3'), ('src1', 'src2')
# Rank None: ('lens3', 'lens3'), ('src1', 'src3')
# Rank None: ('lens3', 'lens3'), ('src2', 'src2')
# Rank None: ('lens3', 'lens3'), ('src2', 'src3')
# Rank None: ('lens3', 'lens3'), ('src3', 'src3')
# Rank None: ('lens4', 'lens4'), ('lens4', 'lens4')
# Rank None: ('lens4', 'lens4'), ('lens0', 'src0')
# Rank None: ('lens4', 'lens4'), ('lens0', 'src1')
# Rank None: ('lens4', 'lens4'), ('lens0', 'src2')
# Rank None: ('lens4', 'lens4'), ('lens0', 'src3')
# Rank None: ('lens4', 'lens4'), ('lens1', 'src0')
# Rank None: ('lens4', 'lens4'), ('lens1', 'src1')
# Rank None: ('lens4', 'lens4'), ('lens1', 'src2')
# Rank None: ('lens4', 'lens4'), ('lens1', 'src3')
# Rank None: ('lens4', 'lens4'), ('lens2', 'src0')
# Rank None: ('lens4', 'lens4'), ('lens2', 'src1')
# Rank None: ('lens4', 'lens4'), ('lens2', 'src2')
# Rank None: ('lens4', 'lens4'), ('lens2', 'src3')
# Rank None: ('lens4', 'lens4'), ('lens3', 'src0')
# Rank None: ('lens4', 'lens4'), ('lens3', 'src1')
# Rank None: ('lens4', 'lens4'), ('lens3', 'src2')
# Rank None: ('lens4', 'lens4'), ('lens3', 'src3')
# Rank None: ('lens4', 'lens4'), ('lens4', 'src0')
# Rank None: ('lens4', 'lens4'), ('lens4', 'src1')
# Rank None: ('lens4', 'lens4'), ('lens4', 'src2')
# Rank None: ('lens4', 'lens4'), ('lens4', 'src3')
# Rank None: ('lens4', 'lens4'), ('src0', 'src0')
# Rank None: ('lens4', 'lens4'), ('src0', 'src1')
# Rank None: ('lens4', 'lens4'), ('src0', 'src2')
# Rank None: ('lens4', 'lens4'), ('src0', 'src3')
# Rank None: ('lens4', 'lens4'), ('src1', 'src1')
# Rank None: ('lens4', 'lens4'), ('src1', 'src2')
# Rank None: ('lens4', 'lens4'), ('src1', 'src3')
# Rank None: ('lens4', 'lens4'), ('src2', 'src2')
# Rank None: ('lens4', 'lens4'), ('src2', 'src3')
# Rank None: ('lens4', 'lens4'), ('src3', 'src3')
# Rank None: ('lens0', 'src0'), ('lens0', 'src0')
# Rank None: ('lens0', 'src0'), ('lens0', 'src1')
# Rank None: ('lens0', 'src0'), ('lens0', 'src2')
# Rank None: ('lens0', 'src0'), ('lens0', 'src3')
# Rank None: ('lens0', 'src0'), ('lens1', 'src0')
# Rank None: ('lens0', 'src0'), ('lens1', 'src1')
# Rank None: ('lens0', 'src0'), ('lens1', 'src2')
# Rank None: ('lens0', 'src0'), ('lens1', 'src3')
# Rank None: ('lens0', 'src0'), ('lens2', 'src0')
# Rank None: ('lens0', 'src0'), ('lens2', 'src1')
# Rank None: ('lens0', 'src0'), ('lens2', 'src2')
# Rank None: ('lens0', 'src0'), ('lens2', 'src3')
# Rank None: ('lens0', 'src0'), ('lens3', 'src0')
# Rank None: ('lens0', 'src0'), ('lens3', 'src1')
# Rank None: ('lens0', 'src0'), ('lens3', 'src2')
# Rank None: ('lens0', 'src0'), ('lens3', 'src3')
# Rank None: ('lens0', 'src0'), ('lens4', 'src0')
# Rank None: ('lens0', 'src0'), ('lens4', 'src1')
# Rank None: ('lens0', 'src0'), ('lens4', 'src2')
# Rank None: ('lens0', 'src0'), ('lens4', 'src3')
# Rank None: ('lens0', 'src0'), ('src0', 'src0')
# Rank None: ('lens0', 'src0'), ('src0', 'src1')
# Rank None: ('lens0', 'src0'), ('src0', 'src2')
# Rank None: ('lens0', 'src0'), ('src0', 'src3')
# Rank None: ('lens0', 'src0'), ('src1', 'src1')
# Rank None: ('lens0', 'src0'), ('src1', 'src2')
# Rank None: ('lens0', 'src0'), ('src1', 'src3')
# Rank None: ('lens0', 'src0'), ('src2', 'src2')
# Rank None: ('lens0', 'src0'), ('src2', 'src3')
# Rank None: ('lens0', 'src0'), ('src3', 'src3')
# Rank None: ('lens0', 'src1'), ('lens0', 'src1')
# Rank None: ('lens0', 'src1'), ('lens0', 'src2')
# Rank None: ('lens0', 'src1'), ('lens0', 'src3')
# Rank None: ('lens0', 'src1'), ('lens1', 'src0')
# Rank None: ('lens0', 'src1'), ('lens1', 'src1')
# Rank None: ('lens0', 'src1'), ('lens1', 'src2')
# Rank None: ('lens0', 'src1'), ('lens1', 'src3')
# Rank None: ('lens0', 'src1'), ('lens2', 'src0')
# Rank None: ('lens0', 'src1'), ('lens2', 'src1')
# Rank None: ('lens0', 'src1'), ('lens2', 'src2')
# Rank None: ('lens0', 'src1'), ('lens2', 'src3')
# Rank None: ('lens0', 'src1'), ('lens3', 'src0')
# Rank None: ('lens0', 'src1'), ('lens3', 'src1')
# Rank None: ('lens0', 'src1'), ('lens3', 'src2')
# Rank None: ('lens0', 'src1'), ('lens3', 'src3')
# Rank None: ('lens0', 'src1'), ('lens4', 'src0')
# Rank None: ('lens0', 'src1'), ('lens4', 'src1')
# Rank None: ('lens0', 'src1'), ('lens4', 'src2')
# Rank None: ('lens0', 'src1'), ('lens4', 'src3')
# Rank None: ('lens0', 'src1'), ('src0', 'src0')
# Rank None: ('lens0', 'src1'), ('src0', 'src1')
# Rank None: ('lens0', 'src1'), ('src0', 'src2')
# Rank None: ('lens0', 'src1'), ('src0', 'src3')
# Rank None: ('lens0', 'src1'), ('src1', 'src1')
# Rank None: ('lens0', 'src1'), ('src1', 'src2')
# Rank None: ('lens0', 'src1'), ('src1', 'src3')
# Rank None: ('lens0', 'src1'), ('src2', 'src2')
# Rank None: ('lens0', 'src1'), ('src2', 'src3')
# Rank None: ('lens0', 'src1'), ('src3', 'src3')
# Rank None: ('lens0', 'src2'), ('lens0', 'src2')
# Rank None: ('lens0', 'src2'), ('lens0', 'src3')
# Rank None: ('lens0', 'src2'), ('lens1', 'src0')
# Rank None: ('lens0', 'src2'), ('lens1', 'src1')
# Rank None: ('lens0', 'src2'), ('lens1', 'src2')
# Rank None: ('lens0', 'src2'), ('lens1', 'src3')
# Rank None: ('lens0', 'src2'), ('lens2', 'src0')
# Rank None: ('lens0', 'src2'), ('lens2', 'src1')
# Rank None: ('lens0', 'src2'), ('lens2', 'src2')
# Rank None: ('lens0', 'src2'), ('lens2', 'src3')
# Rank None: ('lens0', 'src2'), ('lens3', 'src0')
# Rank None: ('lens0', 'src2'), ('lens3', 'src1')
# Rank None: ('lens0', 'src2'), ('lens3', 'src2')
# Rank None: ('lens0', 'src2'), ('lens3', 'src3')
# Rank None: ('lens0', 'src2'), ('lens4', 'src0')
# Rank None: ('lens0', 'src2'), ('lens4', 'src1')
# Rank None: ('lens0', 'src2'), ('lens4', 'src2')
# Rank None: ('lens0', 'src2'), ('lens4', 'src3')
# Rank None: ('lens0', 'src2'), ('src0', 'src0')
# Rank None: ('lens0', 'src2'), ('src0', 'src1')
# Rank None: ('lens0', 'src2'), ('src0', 'src2')
# Rank None: ('lens0', 'src2'), ('src0', 'src3')
# Rank None: ('lens0', 'src2'), ('src1', 'src1')
# Rank None: ('lens0', 'src2'), ('src1', 'src2')
# Rank None: ('lens0', 'src2'), ('src1', 'src3')
# Rank None: ('lens0', 'src2'), ('src2', 'src2')
# Rank None: ('lens0', 'src2'), ('src2', 'src3')
# Rank None: ('lens0', 'src2'), ('src3', 'src3')
# Rank None: ('lens0', 'src3'), ('lens0', 'src3')
# Rank None: ('lens0', 'src3'), ('lens1', 'src0')
# Rank None: ('lens0', 'src3'), ('lens1', 'src1')
# Rank None: ('lens0', 'src3'), ('lens1', 'src2')
# Rank None: ('lens0', 'src3'), ('lens1', 'src3')
# Rank None: ('lens0', 'src3'), ('lens2', 'src0')
# Rank None: ('lens0', 'src3'), ('lens2', 'src1')
# Rank None: ('lens0', 'src3'), ('lens2', 'src2')
# Rank None: ('lens0', 'src3'), ('lens2', 'src3')
# Rank None: ('lens0', 'src3'), ('lens3', 'src0')
# Rank None: ('lens0', 'src3'), ('lens3', 'src1')
# Rank None: ('lens0', 'src3'), ('lens3', 'src2')
# Rank None: ('lens0', 'src3'), ('lens3', 'src3')
# Rank None: ('lens0', 'src3'), ('lens4', 'src0')
# Rank None: ('lens0', 'src3'), ('lens4', 'src1')
# Rank None: ('lens0', 'src3'), ('lens4', 'src2')
# Rank None: ('lens0', 'src3'), ('lens4', 'src3')
# Rank None: ('lens0', 'src3'), ('src0', 'src0')
# Rank None: ('lens0', 'src3'), ('src0', 'src1')
# Rank None: ('lens0', 'src3'), ('src0', 'src2')
# Rank None: ('lens0', 'src3'), ('src0', 'src3')
# Rank None: ('lens0', 'src3'), ('src1', 'src1')
# Rank None: ('lens0', 'src3'), ('src1', 'src2')
# Rank None: ('lens0', 'src3'), ('src1', 'src3')
# Rank None: ('lens0', 'src3'), ('src2', 'src2')
# Rank None: ('lens0', 'src3'), ('src2', 'src3')
# Rank None: ('lens0', 'src3'), ('src3', 'src3')
# Rank None: ('lens1', 'src0'), ('lens1', 'src0')
# Rank None: ('lens1', 'src0'), ('lens1', 'src1')
# Rank None: ('lens1', 'src0'), ('lens1', 'src2')
# Rank None: ('lens1', 'src0'), ('lens1', 'src3')
# Rank None: ('lens1', 'src0'), ('lens2', 'src0')
# Rank None: ('lens1', 'src0'), ('lens2', 'src1')
# Rank None: ('lens1', 'src0'), ('lens2', 'src2')
# Rank None: ('lens1', 'src0'), ('lens2', 'src3')
# Rank None: ('lens1', 'src0'), ('lens3', 'src0')
# Rank None: ('lens1', 'src0'), ('lens3', 'src1')
# Rank None: ('lens1', 'src0'), ('lens3', 'src2')
# Rank None: ('lens1', 'src0'), ('lens3', 'src3')
# Rank None: ('lens1', 'src0'), ('lens4', 'src0')
# Rank None: ('lens1', 'src0'), ('lens4', 'src1')
# Rank None: ('lens1', 'src0'), ('lens4', 'src2')
# Rank None: ('lens1', 'src0'), ('lens4', 'src3')
# Rank None: ('lens1', 'src0'), ('src0', 'src0')
# Rank None: ('lens1', 'src0'), ('src0', 'src1')
# Rank None: ('lens1', 'src0'), ('src0', 'src2')
# Rank None: ('lens1', 'src0'), ('src0', 'src3')
# Rank None: ('lens1', 'src0'), ('src1', 'src1')
# Rank None: ('lens1', 'src0'), ('src1', 'src2')
# Rank None: ('lens1', 'src0'), ('src1', 'src3')
# Rank None: ('lens1', 'src0'), ('src2', 'src2')
# Rank None: ('lens1', 'src0'), ('src2', 'src3')
# Rank None: ('lens1', 'src0'), ('src3', 'src3')
# Rank None: ('lens1', 'src1'), ('lens1', 'src1')
# Rank None: ('lens1', 'src1'), ('lens1', 'src2')
# Rank None: ('lens1', 'src1'), ('lens1', 'src3')
# Rank None: ('lens1', 'src1'), ('lens2', 'src0')
# Rank None: ('lens1', 'src1'), ('lens2', 'src1')
# Rank None: ('lens1', 'src1'), ('lens2', 'src2')
# Rank None: ('lens1', 'src1'), ('lens2', 'src3')
# Rank None: ('lens1', 'src1'), ('lens3', 'src0')
# Rank None: ('lens1', 'src1'), ('lens3', 'src1')
# Rank None: ('lens1', 'src1'), ('lens3', 'src2')
# Rank None: ('lens1', 'src1'), ('lens3', 'src3')
# Rank None: ('lens1', 'src1'), ('lens4', 'src0')
# Rank None: ('lens1', 'src1'), ('lens4', 'src1')
# Rank None: ('lens1', 'src1'), ('lens4', 'src2')
# Rank None: ('lens1', 'src1'), ('lens4', 'src3')
# Rank None: ('lens1', 'src1'), ('src0', 'src0')
# Rank None: ('lens1', 'src1'), ('src0', 'src1')
# Rank None: ('lens1', 'src1'), ('src0', 'src2')
# Rank None: ('lens1', 'src1'), ('src0', 'src3')
# Rank None: ('lens1', 'src1'), ('src1', 'src1')
# Rank None: ('lens1', 'src1'), ('src1', 'src2')
# Rank None: ('lens1', 'src1'), ('src1', 'src3')
# Rank None: ('lens1', 'src1'), ('src2', 'src2')
# Rank None: ('lens1', 'src1'), ('src2', 'src3')
# Rank None: ('lens1', 'src1'), ('src3', 'src3')
# Rank None: ('lens1', 'src2'), ('lens1', 'src2')
# Rank None: ('lens1', 'src2'), ('lens1', 'src3')
# Rank None: ('lens1', 'src2'), ('lens2', 'src0')
# Rank None: ('lens1', 'src2'), ('lens2', 'src1')
# Rank None: ('lens1', 'src2'), ('lens2', 'src2')
# Rank None: ('lens1', 'src2'), ('lens2', 'src3')
# Rank None: ('lens1', 'src2'), ('lens3', 'src0')
# Rank None: ('lens1', 'src2'), ('lens3', 'src1')
# Rank None: ('lens1', 'src2'), ('lens3', 'src2')
# Rank None: ('lens1', 'src2'), ('lens3', 'src3')
# Rank None: ('lens1', 'src2'), ('lens4', 'src0')
# Rank None: ('lens1', 'src2'), ('lens4', 'src1')
# Rank None: ('lens1', 'src2'), ('lens4', 'src2')
# Rank None: ('lens1', 'src2'), ('lens4', 'src3')
# Rank None: ('lens1', 'src2'), ('src0', 'src0')
# Rank None: ('lens1', 'src2'), ('src0', 'src1')
# Rank None: ('lens1', 'src2'), ('src0', 'src2')
# Rank None: ('lens1', 'src2'), ('src0', 'src3')
# Rank None: ('lens1', 'src2'), ('src1', 'src1')
# Rank None: ('lens1', 'src2'), ('src1', 'src2')
# Rank None: ('lens1', 'src2'), ('src1', 'src3')
# Rank None: ('lens1', 'src2'), ('src2', 'src2')
# Rank None: ('lens1', 'src2'), ('src2', 'src3')
# Rank None: ('lens1', 'src2'), ('src3', 'src3')
# Rank None: ('lens1', 'src3'), ('lens1', 'src3')
# Rank None: ('lens1', 'src3'), ('lens2', 'src0')
# Rank None: ('lens1', 'src3'), ('lens2', 'src1')
# Rank None: ('lens1', 'src3'), ('lens2', 'src2')
# Rank None: ('lens1', 'src3'), ('lens2', 'src3')
# Rank None: ('lens1', 'src3'), ('lens3', 'src0')
# Rank None: ('lens1', 'src3'), ('lens3', 'src1')
# Rank None: ('lens1', 'src3'), ('lens3', 'src2')
# Rank None: ('lens1', 'src3'), ('lens3', 'src3')
# Rank None: ('lens1', 'src3'), ('lens4', 'src0')
# Rank None: ('lens1', 'src3'), ('lens4', 'src1')
# Rank None: ('lens1', 'src3'), ('lens4', 'src2')
# Rank None: ('lens1', 'src3'), ('lens4', 'src3')
# Rank None: ('lens1', 'src3'), ('src0', 'src0')
# Rank None: ('lens1', 'src3'), ('src0', 'src1')
# Rank None: ('lens1', 'src3'), ('src0', 'src2')
# Rank None: ('lens1', 'src3'), ('src0', 'src3')
# Rank None: ('lens1', 'src3'), ('src1', 'src1')
# Rank None: ('lens1', 'src3'), ('src1', 'src2')
# Rank None: ('lens1', 'src3'), ('src1', 'src3')
# Rank None: ('lens1', 'src3'), ('src2', 'src2')
# Rank None: ('lens1', 'src3'), ('src2', 'src3')
# Rank None: ('lens1', 'src3'), ('src3', 'src3')
# Rank None: ('lens2', 'src0'), ('lens2', 'src0')
# Rank None: ('lens2', 'src0'), ('lens2', 'src1')
# Rank None: ('lens2', 'src0'), ('lens2', 'src2')
# Rank None: ('lens2', 'src0'), ('lens2', 'src3')
# Rank None: ('lens2', 'src0'), ('lens3', 'src0')
# Rank None: ('lens2', 'src0'), ('lens3', 'src1')
# Rank None: ('lens2', 'src0'), ('lens3', 'src2')
# Rank None: ('lens2', 'src0'), ('lens3', 'src3')
# Rank None: ('lens2', 'src0'), ('lens4', 'src0')
# Rank None: ('lens2', 'src0'), ('lens4', 'src1')
# Rank None: ('lens2', 'src0'), ('lens4', 'src2')
# Rank None: ('lens2', 'src0'), ('lens4', 'src3')
# Rank None: ('lens2', 'src0'), ('src0', 'src0')
# Rank None: ('lens2', 'src0'), ('src0', 'src1')
# Rank None: ('lens2', 'src0'), ('src0', 'src2')
# Rank None: ('lens2', 'src0'), ('src0', 'src3')
# Rank None: ('lens2', 'src0'), ('src1', 'src1')
# Rank None: ('lens2', 'src0'), ('src1', 'src2')
# Rank None: ('lens2', 'src0'), ('src1', 'src3')
# Rank None: ('lens2', 'src0'), ('src2', 'src2')
# Rank None: ('lens2', 'src0'), ('src2', 'src3')
# Rank None: ('lens2', 'src0'), ('src3', 'src3')
# Rank None: ('lens2', 'src1'), ('lens2', 'src1')
# Rank None: ('lens2', 'src1'), ('lens2', 'src2')
# Rank None: ('lens2', 'src1'), ('lens2', 'src3')
# Rank None: ('lens2', 'src1'), ('lens3', 'src0')
# Rank None: ('lens2', 'src1'), ('lens3', 'src1')
# Rank None: ('lens2', 'src1'), ('lens3', 'src2')
# Rank None: ('lens2', 'src1'), ('lens3', 'src3')
# Rank None: ('lens2', 'src1'), ('lens4', 'src0')
# Rank None: ('lens2', 'src1'), ('lens4', 'src1')
# Rank None: ('lens2', 'src1'), ('lens4', 'src2')
# Rank None: ('lens2', 'src1'), ('lens4', 'src3')
# Rank None: ('lens2', 'src1'), ('src0', 'src0')
# Rank None: ('lens2', 'src1'), ('src0', 'src1')
# Rank None: ('lens2', 'src1'), ('src0', 'src2')
# Rank None: ('lens2', 'src1'), ('src0', 'src3')
# Rank None: ('lens2', 'src1'), ('src1', 'src1')
# Rank None: ('lens2', 'src1'), ('src1', 'src2')
# Rank None: ('lens2', 'src1'), ('src1', 'src3')
# Rank None: ('lens2', 'src1'), ('src2', 'src2')
# Rank None: ('lens2', 'src1'), ('src2', 'src3')
# Rank None: ('lens2', 'src1'), ('src3', 'src3')
# Rank None: ('lens2', 'src2'), ('lens2', 'src2')
# Rank None: ('lens2', 'src2'), ('lens2', 'src3')
# Rank None: ('lens2', 'src2'), ('lens3', 'src0')
# Rank None: ('lens2', 'src2'), ('lens3', 'src1')
# Rank None: ('lens2', 'src2'), ('lens3', 'src2')
# Rank None: ('lens2', 'src2'), ('lens3', 'src3')
# Rank None: ('lens2', 'src2'), ('lens4', 'src0')
# Rank None: ('lens2', 'src2'), ('lens4', 'src1')
# Rank None: ('lens2', 'src2'), ('lens4', 'src2')
# Rank None: ('lens2', 'src2'), ('lens4', 'src3')
# Rank None: ('lens2', 'src2'), ('src0', 'src0')
# Rank None: ('lens2', 'src2'), ('src0', 'src1')
# Rank None: ('lens2', 'src2'), ('src0', 'src2')
# Rank None: ('lens2', 'src2'), ('src0', 'src3')
# Rank None: ('lens2', 'src2'), ('src1', 'src1')
# Rank None: ('lens2', 'src2'), ('src1', 'src2')
# Rank None: ('lens2', 'src2'), ('src1', 'src3')
# Rank None: ('lens2', 'src2'), ('src2', 'src2')
# Rank None: ('lens2', 'src2'), ('src2', 'src3')
# Rank None: ('lens2', 'src2'), ('src3', 'src3')
# Rank None: ('lens2', 'src3'), ('lens2', 'src3')
# Rank None: ('lens2', 'src3'), ('lens3', 'src0')
# Rank None: ('lens2', 'src3'), ('lens3', 'src1')
# Rank None: ('lens2', 'src3'), ('lens3', 'src2')
# Rank None: ('lens2', 'src3'), ('lens3', 'src3')
# Rank None: ('lens2', 'src3'), ('lens4', 'src0')
# Rank None: ('lens2', 'src3'), ('lens4', 'src1')
# Rank None: ('lens2', 'src3'), ('lens4', 'src2')
# Rank None: ('lens2', 'src3'), ('lens4', 'src3')
# Rank None: ('lens2', 'src3'), ('src0', 'src0')
# Rank None: ('lens2', 'src3'), ('src0', 'src1')
# Rank None: ('lens2', 'src3'), ('src0', 'src2')
# Rank None: ('lens2', 'src3'), ('src0', 'src3')
# Rank None: ('lens2', 'src3'), ('src1', 'src1')
# Rank None: ('lens2', 'src3'), ('src1', 'src2')
# Rank None: ('lens2', 'src3'), ('src1', 'src3')
# Rank None: ('lens2', 'src3'), ('src2', 'src2')
# Rank None: ('lens2', 'src3'), ('src2', 'src3')
# Rank None: ('lens2', 'src3'), ('src3', 'src3')
# Rank None: ('lens3', 'src0'), ('lens3', 'src0')
# Rank None: ('lens3', 'src0'), ('lens3', 'src1')
# Rank None: ('lens3', 'src0'), ('lens3', 'src2')
# Rank None: ('lens3', 'src0'), ('lens3', 'src3')
# Rank None: ('lens3', 'src0'), ('lens4', 'src0')
# Rank None: ('lens3', 'src0'), ('lens4', 'src1')
# Rank None: ('lens3', 'src0'), ('lens4', 'src2')
# Rank None: ('lens3', 'src0'), ('lens4', 'src3')
# Rank None: ('lens3', 'src0'), ('src0', 'src0')
# Rank None: ('lens3', 'src0'), ('src0', 'src1')
# Rank None: ('lens3', 'src0'), ('src0', 'src2')
# Rank None: ('lens3', 'src0'), ('src0', 'src3')
# Rank None: ('lens3', 'src0'), ('src1', 'src1')
# Rank None: ('lens3', 'src0'), ('src1', 'src2')
# Rank None: ('lens3', 'src0'), ('src1', 'src3')
# Rank None: ('lens3', 'src0'), ('src2', 'src2')
# Rank None: ('lens3', 'src0'), ('src2', 'src3')
# Rank None: ('lens3', 'src0'), ('src3', 'src3')
# Rank None: ('lens3', 'src1'), ('lens3', 'src1')
# Rank None: ('lens3', 'src1'), ('lens3', 'src2')
# Rank None: ('lens3', 'src1'), ('lens3', 'src3')
# Rank None: ('lens3', 'src1'), ('lens4', 'src0')
# Rank None: ('lens3', 'src1'), ('lens4', 'src1')
# Rank None: ('lens3', 'src1'), ('lens4', 'src2')
# Rank None: ('lens3', 'src1'), ('lens4', 'src3')
# Rank None: ('lens3', 'src1'), ('src0', 'src0')
# Rank None: ('lens3', 'src1'), ('src0', 'src1')
# Rank None: ('lens3', 'src1'), ('src0', 'src2')
# Rank None: ('lens3', 'src1'), ('src0', 'src3')
# Rank None: ('lens3', 'src1'), ('src1', 'src1')
# Rank None: ('lens3', 'src1'), ('src1', 'src2')
# Rank None: ('lens3', 'src1'), ('src1', 'src3')
# Rank None: ('lens3', 'src1'), ('src2', 'src2')
# Rank None: ('lens3', 'src1'), ('src2', 'src3')
# Rank None: ('lens3', 'src1'), ('src3', 'src3')
# Rank None: ('lens3', 'src2'), ('lens3', 'src2')
# Rank None: ('lens3', 'src2'), ('lens3', 'src3')
# Rank None: ('lens3', 'src2'), ('lens4', 'src0')
# Rank None: ('lens3', 'src2'), ('lens4', 'src1')
# Rank None: ('lens3', 'src2'), ('lens4', 'src2')
# Rank None: ('lens3', 'src2'), ('lens4', 'src3')
# Rank None: ('lens3', 'src2'), ('src0', 'src0')
# Rank None: ('lens3', 'src2'), ('src0', 'src1')
# Rank None: ('lens3', 'src2'), ('src0', 'src2')
# Rank None: ('lens3', 'src2'), ('src0', 'src3')
# Rank None: ('lens3', 'src2'), ('src1', 'src1')
# Rank None: ('lens3', 'src2'), ('src1', 'src2')
# Rank None: ('lens3', 'src2'), ('src1', 'src3')
# Rank None: ('lens3', 'src2'), ('src2', 'src2')
# Rank None: ('lens3', 'src2'), ('src2', 'src3')
# Rank None: ('lens3', 'src2'), ('src3', 'src3')
# Rank None: ('lens3', 'src3'), ('lens3', 'src3')
# Rank None: ('lens3', 'src3'), ('lens4', 'src0')
# Rank None: ('lens3', 'src3'), ('lens4', 'src1')
# Rank None: ('lens3', 'src3'), ('lens4', 'src2')
# Rank None: ('lens3', 'src3'), ('lens4', 'src3')
# Rank None: ('lens3', 'src3'), ('src0', 'src0')
# Rank None: ('lens3', 'src3'), ('src0', 'src1')
# Rank None: ('lens3', 'src3'), ('src0', 'src2')
# Rank None: ('lens3', 'src3'), ('src0', 'src3')
# Rank None: ('lens3', 'src3'), ('src1', 'src1')
# Rank None: ('lens3', 'src3'), ('src1', 'src2')
# Rank None: ('lens3', 'src3'), ('src1', 'src3')
# Rank None: ('lens3', 'src3'), ('src2', 'src2')
# Rank None: ('lens3', 'src3'), ('src2', 'src3')
# Rank None: ('lens3', 'src3'), ('src3', 'src3')
# Rank None: ('lens4', 'src0'), ('lens4', 'src0')
# Rank None: ('lens4', 'src0'), ('lens4', 'src1')
# Rank None: ('lens4', 'src0'), ('lens4', 'src2')
# Rank None: ('lens4', 'src0'), ('lens4', 'src3')
# Rank None: ('lens4', 'src0'), ('src0', 'src0')
# Rank None: ('lens4', 'src0'), ('src0', 'src1')
# Rank None: ('lens4', 'src0'), ('src0', 'src2')
# Rank None: ('lens4', 'src0'), ('src0', 'src3')
# Rank None: ('lens4', 'src0'), ('src1', 'src1')
# Rank None: ('lens4', 'src0'), ('src1', 'src2')
# Rank None: ('lens4', 'src0'), ('src1', 'src3')
# Rank None: ('lens4', 'src0'), ('src2', 'src2')
# Rank None: ('lens4', 'src0'), ('src2', 'src3')
# Rank None: ('lens4', 'src0'), ('src3', 'src3')
# Rank None: ('lens4', 'src1'), ('lens4', 'src1')
# Rank None: ('lens4', 'src1'), ('lens4', 'src2')
# Rank None: ('lens4', 'src1'), ('lens4', 'src3')
# Rank None: ('lens4', 'src1'), ('src0', 'src0')
# Rank None: ('lens4', 'src1'), ('src0', 'src1')
# Rank None: ('lens4', 'src1'), ('src0', 'src2')
# Rank None: ('lens4', 'src1'), ('src0', 'src3')
# Rank None: ('lens4', 'src1'), ('src1', 'src1')
# Rank None: ('lens4', 'src1'), ('src1', 'src2')
# Rank None: ('lens4', 'src1'), ('src1', 'src3')
# Rank None: ('lens4', 'src1'), ('src2', 'src2')
# Rank None: ('lens4', 'src1'), ('src2', 'src3')
# Rank None: ('lens4', 'src1'), ('src3', 'src3')
# Rank None: ('lens4', 'src2'), ('lens4', 'src2')
# Rank None: ('lens4', 'src2'), ('lens4', 'src3')
# Rank None: ('lens4', 'src2'), ('src0', 'src0')
# Rank None: ('lens4', 'src2'), ('src0', 'src1')
# Rank None: ('lens4', 'src2'), ('src0', 'src2')
# Rank None: ('lens4', 'src2'), ('src0', 'src3')
# Rank None: ('lens4', 'src2'), ('src1', 'src1')
# Rank None: ('lens4', 'src2'), ('src1', 'src2')
# Rank None: ('lens4', 'src2'), ('src1', 'src3')
# Rank None: ('lens4', 'src2'), ('src2', 'src2')
# Rank None: ('lens4', 'src2'), ('src2', 'src3')
# Rank None: ('lens4', 'src2'), ('src3', 'src3')
# Rank None: ('lens4', 'src3'), ('lens4', 'src3')
# Rank None: ('lens4', 'src3'), ('src0', 'src0')
# Rank None: ('lens4', 'src3'), ('src0', 'src1')
# Rank None: ('lens4', 'src3'), ('src0', 'src2')
# Rank None: ('lens4', 'src3'), ('src0', 'src3')
# Rank None: ('lens4', 'src3'), ('src1', 'src1')
# Rank None: ('lens4', 'src3'), ('src1', 'src2')
# Rank None: ('lens4', 'src3'), ('src1', 'src3')
# Rank None: ('lens4', 'src3'), ('src2', 'src2')
# Rank None: ('lens4', 'src3'), ('src2', 'src3')
# Rank None: ('lens4', 'src3'), ('src3', 'src3')
# Rank None: ('src0', 'src0'), ('src0', 'src0')
# Rank None: ('src0', 'src0'), ('src0', 'src1')
# Rank None: ('src0', 'src0'), ('src0', 'src2')
# Rank None: ('src0', 'src0'), ('src0', 'src3')
# Rank None: ('src0', 'src0'), ('src1', 'src1')
# Rank None: ('src0', 'src0'), ('src1', 'src2')
# Rank None: ('src0', 'src0'), ('src1', 'src3')
# Rank None: ('src0', 'src0'), ('src2', 'src2')
# Rank None: ('src0', 'src0'), ('src2', 'src3')
# Rank None: ('src0', 'src0'), ('src3', 'src3')
# Rank None: ('src0', 'src1'), ('src0', 'src1')
# Rank None: ('src0', 'src1'), ('src0', 'src2')
# Rank None: ('src0', 'src1'), ('src0', 'src3')
# Rank None: ('src0', 'src1'), ('src1', 'src1')
# Rank None: ('src0', 'src1'), ('src1', 'src2')
# Rank None: ('src0', 'src1'), ('src1', 'src3')
# Rank None: ('src0', 'src1'), ('src2', 'src2')
# Rank None: ('src0', 'src1'), ('src2', 'src3')
# Rank None: ('src0', 'src1'), ('src3', 'src3')
# Rank None: ('src0', 'src2'), ('src0', 'src2')
# Rank None: ('src0', 'src2'), ('src0', 'src3')
# Rank None: ('src0', 'src2'), ('src1', 'src1')
# Rank None: ('src0', 'src2'), ('src1', 'src2')
# Rank None: ('src0', 'src2'), ('src1', 'src3')
# Rank None: ('src0', 'src2'), ('src2', 'src2')
# Rank None: ('src0', 'src2'), ('src2', 'src3')
# Rank None: ('src0', 'src2'), ('src3', 'src3')
# Rank None: ('src0', 'src3'), ('src0', 'src3')
# Rank None: ('src0', 'src3'), ('src1', 'src1')
# Rank None: ('src0', 'src3'), ('src1', 'src2')
# Rank None: ('src0', 'src3'), ('src1', 'src3')
# Rank None: ('src0', 'src3'), ('src2', 'src2')
# Rank None: ('src0', 'src3'), ('src2', 'src3')
# Rank None: ('src0', 'src3'), ('src3', 'src3')
# Rank None: ('src1', 'src1'), ('src1', 'src1')
# Rank None: ('src1', 'src1'), ('src1', 'src2')
# Rank None: ('src1', 'src1'), ('src1', 'src3')
# Rank None: ('src1', 'src1'), ('src2', 'src2')
# Rank None: ('src1', 'src1'), ('src2', 'src3')
# Rank None: ('src1', 'src1'), ('src3', 'src3')
# Rank None: ('src1', 'src2'), ('src1', 'src2')
# Rank None: ('src1', 'src2'), ('src1', 'src3')
# Rank None: ('src1', 'src2'), ('src2', 'src2')
# Rank None: ('src1', 'src2'), ('src2', 'src3')
# Rank None: ('src1', 'src2'), ('src3', 'src3')
# Rank None: ('src1', 'src3'), ('src1', 'src3')
# Rank None: ('src1', 'src3'), ('src2', 'src2')
# Rank None: ('src1', 'src3'), ('src2', 'src3')
# Rank None: ('src1', 'src3'), ('src3', 'src3')
# Rank None: ('src2', 'src2'), ('src2', 'src2')
# Rank None: ('src2', 'src2'), ('src2', 'src3')
# Rank None: ('src2', 'src2'), ('src3', 'src3')
# Rank None: ('src2', 'src3'), ('src2', 'src3')
# Rank None: ('src2', 'src3'), ('src3', 'src3')
# Rank None: ('src3', 'src3'), ('src3', 'src3')
# Building the covariance: placing blocks in their place
# ('lens0', 'lens0') ('lens0', 'lens0')
# ('lens0', 'lens0') ('lens1', 'lens1')
# ('lens0', 'lens0') ('lens2', 'lens2')
# ('lens0', 'lens0') ('lens3', 'lens3')
# ('lens0', 'lens0') ('lens4', 'lens4')
# ('lens0', 'lens0') ('lens0', 'src0')
# ('lens0', 'lens0') ('lens0', 'src1')
# ('lens0', 'lens0') ('lens0', 'src2')
# ('lens0', 'lens0') ('lens0', 'src3')
# ('lens0', 'lens0') ('lens1', 'src0')
# ('lens0', 'lens0') ('lens1', 'src1')
# ('lens0', 'lens0') ('lens1', 'src2')
# ('lens0', 'lens0') ('lens1', 'src3')
# ('lens0', 'lens0') ('lens2', 'src0')
# ('lens0', 'lens0') ('lens2', 'src1')
# ('lens0', 'lens0') ('lens2', 'src2')
# ('lens0', 'lens0') ('lens2', 'src3')
# ('lens0', 'lens0') ('lens3', 'src0')
# ('lens0', 'lens0') ('lens3', 'src1')
# ('lens0', 'lens0') ('lens3', 'src2')
# ('lens0', 'lens0') ('lens3', 'src3')
# ('lens0', 'lens0') ('lens4', 'src0')
# ('lens0', 'lens0') ('lens4', 'src1')
# ('lens0', 'lens0') ('lens4', 'src2')
# ('lens0', 'lens0') ('lens4', 'src3')
# ('lens0', 'lens0') ('src0', 'src0')
# ('lens0', 'lens0') ('src0', 'src1')
# ('lens0', 'lens0') ('src0', 'src2')
# ('lens0', 'lens0') ('src0', 'src3')
# ('lens0', 'lens0') ('src1', 'src1')
# ('lens0', 'lens0') ('src1', 'src2')
# ('lens0', 'lens0') ('src1', 'src3')
# ('lens0', 'lens0') ('src2', 'src2')
# ('lens0', 'lens0') ('src2', 'src3')
# ('lens0', 'lens0') ('src3', 'src3')
# ('lens1', 'lens1') ('lens1', 'lens1')
# ('lens1', 'lens1') ('lens2', 'lens2')
# ('lens1', 'lens1') ('lens3', 'lens3')
# ('lens1', 'lens1') ('lens4', 'lens4')
# ('lens1', 'lens1') ('lens0', 'src0')
# ('lens1', 'lens1') ('lens0', 'src1')
# ('lens1', 'lens1') ('lens0', 'src2')
# ('lens1', 'lens1') ('lens0', 'src3')
# ('lens1', 'lens1') ('lens1', 'src0')
# ('lens1', 'lens1') ('lens1', 'src1')
# ('lens1', 'lens1') ('lens1', 'src2')
# ('lens1', 'lens1') ('lens1', 'src3')
# ('lens1', 'lens1') ('lens2', 'src0')
# ('lens1', 'lens1') ('lens2', 'src1')
# ('lens1', 'lens1') ('lens2', 'src2')
# ('lens1', 'lens1') ('lens2', 'src3')
# ('lens1', 'lens1') ('lens3', 'src0')
# ('lens1', 'lens1') ('lens3', 'src1')
# ('lens1', 'lens1') ('lens3', 'src2')
# ('lens1', 'lens1') ('lens3', 'src3')
# ('lens1', 'lens1') ('lens4', 'src0')
# ('lens1', 'lens1') ('lens4', 'src1')
# ('lens1', 'lens1') ('lens4', 'src2')
# ('lens1', 'lens1') ('lens4', 'src3')
# ('lens1', 'lens1') ('src0', 'src0')
# ('lens1', 'lens1') ('src0', 'src1')
# ('lens1', 'lens1') ('src0', 'src2')
# ('lens1', 'lens1') ('src0', 'src3')
# ('lens1', 'lens1') ('src1', 'src1')
# ('lens1', 'lens1') ('src1', 'src2')
# ('lens1', 'lens1') ('src1', 'src3')
# ('lens1', 'lens1') ('src2', 'src2')
# ('lens1', 'lens1') ('src2', 'src3')
# ('lens1', 'lens1') ('src3', 'src3')
# ('lens2', 'lens2') ('lens2', 'lens2')
# ('lens2', 'lens2') ('lens3', 'lens3')
# ('lens2', 'lens2') ('lens4', 'lens4')
# ('lens2', 'lens2') ('lens0', 'src0')
# ('lens2', 'lens2') ('lens0', 'src1')
# ('lens2', 'lens2') ('lens0', 'src2')
# ('lens2', 'lens2') ('lens0', 'src3')
# ('lens2', 'lens2') ('lens1', 'src0')
# ('lens2', 'lens2') ('lens1', 'src1')
# ('lens2', 'lens2') ('lens1', 'src2')
# ('lens2', 'lens2') ('lens1', 'src3')
# ('lens2', 'lens2') ('lens2', 'src0')
# ('lens2', 'lens2') ('lens2', 'src1')
# ('lens2', 'lens2') ('lens2', 'src2')
# ('lens2', 'lens2') ('lens2', 'src3')
# ('lens2', 'lens2') ('lens3', 'src0')
# ('lens2', 'lens2') ('lens3', 'src1')
# ('lens2', 'lens2') ('lens3', 'src2')
# ('lens2', 'lens2') ('lens3', 'src3')
# ('lens2', 'lens2') ('lens4', 'src0')
# ('lens2', 'lens2') ('lens4', 'src1')
# ('lens2', 'lens2') ('lens4', 'src2')
# ('lens2', 'lens2') ('lens4', 'src3')
# ('lens2', 'lens2') ('src0', 'src0')
# ('lens2', 'lens2') ('src0', 'src1')
# ('lens2', 'lens2') ('src0', 'src2')
# ('lens2', 'lens2') ('src0', 'src3')
# ('lens2', 'lens2') ('src1', 'src1')
# ('lens2', 'lens2') ('src1', 'src2')
# ('lens2', 'lens2') ('src1', 'src3')
# ('lens2', 'lens2') ('src2', 'src2')
# ('lens2', 'lens2') ('src2', 'src3')
# ('lens2', 'lens2') ('src3', 'src3')
# ('lens3', 'lens3') ('lens3', 'lens3')
# ('lens3', 'lens3') ('lens4', 'lens4')
# ('lens3', 'lens3') ('lens0', 'src0')
# ('lens3', 'lens3') ('lens0', 'src1')
# ('lens3', 'lens3') ('lens0', 'src2')
# ('lens3', 'lens3') ('lens0', 'src3')
# ('lens3', 'lens3') ('lens1', 'src0')
# ('lens3', 'lens3') ('lens1', 'src1')
# ('lens3', 'lens3') ('lens1', 'src2')
# ('lens3', 'lens3') ('lens1', 'src3')
# ('lens3', 'lens3') ('lens2', 'src0')
# ('lens3', 'lens3') ('lens2', 'src1')
# ('lens3', 'lens3') ('lens2', 'src2')
# ('lens3', 'lens3') ('lens2', 'src3')
# ('lens3', 'lens3') ('lens3', 'src0')
# ('lens3', 'lens3') ('lens3', 'src1')
# ('lens3', 'lens3') ('lens3', 'src2')
# ('lens3', 'lens3') ('lens3', 'src3')
# ('lens3', 'lens3') ('lens4', 'src0')
# ('lens3', 'lens3') ('lens4', 'src1')
# ('lens3', 'lens3') ('lens4', 'src2')
# ('lens3', 'lens3') ('lens4', 'src3')
# ('lens3', 'lens3') ('src0', 'src0')
# ('lens3', 'lens3') ('src0', 'src1')
# ('lens3', 'lens3') ('src0', 'src2')
# ('lens3', 'lens3') ('src0', 'src3')
# ('lens3', 'lens3') ('src1', 'src1')
# ('lens3', 'lens3') ('src1', 'src2')
# ('lens3', 'lens3') ('src1', 'src3')
# ('lens3', 'lens3') ('src2', 'src2')
# ('lens3', 'lens3') ('src2', 'src3')
# ('lens3', 'lens3') ('src3', 'src3')
# ('lens4', 'lens4') ('lens4', 'lens4')
# ('lens4', 'lens4') ('lens0', 'src0')
# ('lens4', 'lens4') ('lens0', 'src1')
# ('lens4', 'lens4') ('lens0', 'src2')
# ('lens4', 'lens4') ('lens0', 'src3')
# ('lens4', 'lens4') ('lens1', 'src0')
# ('lens4', 'lens4') ('lens1', 'src1')
# ('lens4', 'lens4') ('lens1', 'src2')
# ('lens4', 'lens4') ('lens1', 'src3')
# ('lens4', 'lens4') ('lens2', 'src0')
# ('lens4', 'lens4') ('lens2', 'src1')
# ('lens4', 'lens4') ('lens2', 'src2')
# ('lens4', 'lens4') ('lens2', 'src3')
# ('lens4', 'lens4') ('lens3', 'src0')
# ('lens4', 'lens4') ('lens3', 'src1')
# ('lens4', 'lens4') ('lens3', 'src2')
# ('lens4', 'lens4') ('lens3', 'src3')
# ('lens4', 'lens4') ('lens4', 'src0')
# ('lens4', 'lens4') ('lens4', 'src1')
# ('lens4', 'lens4') ('lens4', 'src2')
# ('lens4', 'lens4') ('lens4', 'src3')
# ('lens4', 'lens4') ('src0', 'src0')
# ('lens4', 'lens4') ('src0', 'src1')
# ('lens4', 'lens4') ('src0', 'src2')
# ('lens4', 'lens4') ('src0', 'src3')
# ('lens4', 'lens4') ('src1', 'src1')
# ('lens4', 'lens4') ('src1', 'src2')
# ('lens4', 'lens4') ('src1', 'src3')
# ('lens4', 'lens4') ('src2', 'src2')
# ('lens4', 'lens4') ('src2', 'src3')
# ('lens4', 'lens4') ('src3', 'src3')
# ('lens0', 'src0') ('lens0', 'src0')
# ('lens0', 'src0') ('lens0', 'src1')
# ('lens0', 'src0') ('lens0', 'src2')
# ('lens0', 'src0') ('lens0', 'src3')
# ('lens0', 'src0') ('lens1', 'src0')
# ('lens0', 'src0') ('lens1', 'src1')
# ('lens0', 'src0') ('lens1', 'src2')
# ('lens0', 'src0') ('lens1', 'src3')
# ('lens0', 'src0') ('lens2', 'src0')
# ('lens0', 'src0') ('lens2', 'src1')
# ('lens0', 'src0') ('lens2', 'src2')
# ('lens0', 'src0') ('lens2', 'src3')
# ('lens0', 'src0') ('lens3', 'src0')
# ('lens0', 'src0') ('lens3', 'src1')
# ('lens0', 'src0') ('lens3', 'src2')
# ('lens0', 'src0') ('lens3', 'src3')
# ('lens0', 'src0') ('lens4', 'src0')
# ('lens0', 'src0') ('lens4', 'src1')
# ('lens0', 'src0') ('lens4', 'src2')
# ('lens0', 'src0') ('lens4', 'src3')
# ('lens0', 'src0') ('src0', 'src0')
# ('lens0', 'src0') ('src0', 'src1')
# ('lens0', 'src0') ('src0', 'src2')
# ('lens0', 'src0') ('src0', 'src3')
# ('lens0', 'src0') ('src1', 'src1')
# ('lens0', 'src0') ('src1', 'src2')
# ('lens0', 'src0') ('src1', 'src3')
# ('lens0', 'src0') ('src2', 'src2')
# ('lens0', 'src0') ('src2', 'src3')
# ('lens0', 'src0') ('src3', 'src3')
# ('lens0', 'src1') ('lens0', 'src1')
# ('lens0', 'src1') ('lens0', 'src2')
# ('lens0', 'src1') ('lens0', 'src3')
# ('lens0', 'src1') ('lens1', 'src0')
# ('lens0', 'src1') ('lens1', 'src1')
# ('lens0', 'src1') ('lens1', 'src2')
# ('lens0', 'src1') ('lens1', 'src3')
# ('lens0', 'src1') ('lens2', 'src0')
# ('lens0', 'src1') ('lens2', 'src1')
# ('lens0', 'src1') ('lens2', 'src2')
# ('lens0', 'src1') ('lens2', 'src3')
# ('lens0', 'src1') ('lens3', 'src0')
# ('lens0', 'src1') ('lens3', 'src1')
# ('lens0', 'src1') ('lens3', 'src2')
# ('lens0', 'src1') ('lens3', 'src3')
# ('lens0', 'src1') ('lens4', 'src0')
# ('lens0', 'src1') ('lens4', 'src1')
# ('lens0', 'src1') ('lens4', 'src2')
# ('lens0', 'src1') ('lens4', 'src3')
# ('lens0', 'src1') ('src0', 'src0')
# ('lens0', 'src1') ('src0', 'src1')
# ('lens0', 'src1') ('src0', 'src2')
# ('lens0', 'src1') ('src0', 'src3')
# ('lens0', 'src1') ('src1', 'src1')
# ('lens0', 'src1') ('src1', 'src2')
# ('lens0', 'src1') ('src1', 'src3')
# ('lens0', 'src1') ('src2', 'src2')
# ('lens0', 'src1') ('src2', 'src3')
# ('lens0', 'src1') ('src3', 'src3')
# ('lens0', 'src2') ('lens0', 'src2')
# ('lens0', 'src2') ('lens0', 'src3')
# ('lens0', 'src2') ('lens1', 'src0')
# ('lens0', 'src2') ('lens1', 'src1')
# ('lens0', 'src2') ('lens1', 'src2')
# ('lens0', 'src2') ('lens1', 'src3')
# ('lens0', 'src2') ('lens2', 'src0')
# ('lens0', 'src2') ('lens2', 'src1')
# ('lens0', 'src2') ('lens2', 'src2')
# ('lens0', 'src2') ('lens2', 'src3')
# ('lens0', 'src2') ('lens3', 'src0')
# ('lens0', 'src2') ('lens3', 'src1')
# ('lens0', 'src2') ('lens3', 'src2')
# ('lens0', 'src2') ('lens3', 'src3')
# ('lens0', 'src2') ('lens4', 'src0')
# ('lens0', 'src2') ('lens4', 'src1')
# ('lens0', 'src2') ('lens4', 'src2')
# ('lens0', 'src2') ('lens4', 'src3')
# ('lens0', 'src2') ('src0', 'src0')
# ('lens0', 'src2') ('src0', 'src1')
# ('lens0', 'src2') ('src0', 'src2')
# ('lens0', 'src2') ('src0', 'src3')
# ('lens0', 'src2') ('src1', 'src1')
# ('lens0', 'src2') ('src1', 'src2')
# ('lens0', 'src2') ('src1', 'src3')
# ('lens0', 'src2') ('src2', 'src2')
# ('lens0', 'src2') ('src2', 'src3')
# ('lens0', 'src2') ('src3', 'src3')
# ('lens0', 'src3') ('lens0', 'src3')
# ('lens0', 'src3') ('lens1', 'src0')
# ('lens0', 'src3') ('lens1', 'src1')
# ('lens0', 'src3') ('lens1', 'src2')
# ('lens0', 'src3') ('lens1', 'src3')
# ('lens0', 'src3') ('lens2', 'src0')
# ('lens0', 'src3') ('lens2', 'src1')
# ('lens0', 'src3') ('lens2', 'src2')
# ('lens0', 'src3') ('lens2', 'src3')
# ('lens0', 'src3') ('lens3', 'src0')
# ('lens0', 'src3') ('lens3', 'src1')
# ('lens0', 'src3') ('lens3', 'src2')
# ('lens0', 'src3') ('lens3', 'src3')
# ('lens0', 'src3') ('lens4', 'src0')
# ('lens0', 'src3') ('lens4', 'src1')
# ('lens0', 'src3') ('lens4', 'src2')
# ('lens0', 'src3') ('lens4', 'src3')
# ('lens0', 'src3') ('src0', 'src0')
# ('lens0', 'src3') ('src0', 'src1')
# ('lens0', 'src3') ('src0', 'src2')
# ('lens0', 'src3') ('src0', 'src3')
# ('lens0', 'src3') ('src1', 'src1')
# ('lens0', 'src3') ('src1', 'src2')
# ('lens0', 'src3') ('src1', 'src3')
# ('lens0', 'src3') ('src2', 'src2')
# ('lens0', 'src3') ('src2', 'src3')
# ('lens0', 'src3') ('src3', 'src3')
# ('lens1', 'src0') ('lens1', 'src0')
# ('lens1', 'src0') ('lens1', 'src1')
# ('lens1', 'src0') ('lens1', 'src2')
# ('lens1', 'src0') ('lens1', 'src3')
# ('lens1', 'src0') ('lens2', 'src0')
# ('lens1', 'src0') ('lens2', 'src1')
# ('lens1', 'src0') ('lens2', 'src2')
# ('lens1', 'src0') ('lens2', 'src3')
# ('lens1', 'src0') ('lens3', 'src0')
# ('lens1', 'src0') ('lens3', 'src1')
# ('lens1', 'src0') ('lens3', 'src2')
# ('lens1', 'src0') ('lens3', 'src3')
# ('lens1', 'src0') ('lens4', 'src0')
# ('lens1', 'src0') ('lens4', 'src1')
# ('lens1', 'src0') ('lens4', 'src2')
# ('lens1', 'src0') ('lens4', 'src3')
# ('lens1', 'src0') ('src0', 'src0')
# ('lens1', 'src0') ('src0', 'src1')
# ('lens1', 'src0') ('src0', 'src2')
# ('lens1', 'src0') ('src0', 'src3')
# ('lens1', 'src0') ('src1', 'src1')
# ('lens1', 'src0') ('src1', 'src2')
# ('lens1', 'src0') ('src1', 'src3')
# ('lens1', 'src0') ('src2', 'src2')
# ('lens1', 'src0') ('src2', 'src3')
# ('lens1', 'src0') ('src3', 'src3')
# ('lens1', 'src1') ('lens1', 'src1')
# ('lens1', 'src1') ('lens1', 'src2')
# ('lens1', 'src1') ('lens1', 'src3')
# ('lens1', 'src1') ('lens2', 'src0')
# ('lens1', 'src1') ('lens2', 'src1')
# ('lens1', 'src1') ('lens2', 'src2')
# ('lens1', 'src1') ('lens2', 'src3')
# ('lens1', 'src1') ('lens3', 'src0')
# ('lens1', 'src1') ('lens3', 'src1')
# ('lens1', 'src1') ('lens3', 'src2')
# ('lens1', 'src1') ('lens3', 'src3')
# ('lens1', 'src1') ('lens4', 'src0')
# ('lens1', 'src1') ('lens4', 'src1')
# ('lens1', 'src1') ('lens4', 'src2')
# ('lens1', 'src1') ('lens4', 'src3')
# ('lens1', 'src1') ('src0', 'src0')
# ('lens1', 'src1') ('src0', 'src1')
# ('lens1', 'src1') ('src0', 'src2')
# ('lens1', 'src1') ('src0', 'src3')
# ('lens1', 'src1') ('src1', 'src1')
# ('lens1', 'src1') ('src1', 'src2')
# ('lens1', 'src1') ('src1', 'src3')
# ('lens1', 'src1') ('src2', 'src2')
# ('lens1', 'src1') ('src2', 'src3')
# ('lens1', 'src1') ('src3', 'src3')
# ('lens1', 'src2') ('lens1', 'src2')
# ('lens1', 'src2') ('lens1', 'src3')
# ('lens1', 'src2') ('lens2', 'src0')
# ('lens1', 'src2') ('lens2', 'src1')
# ('lens1', 'src2') ('lens2', 'src2')
# ('lens1', 'src2') ('lens2', 'src3')
# ('lens1', 'src2') ('lens3', 'src0')
# ('lens1', 'src2') ('lens3', 'src1')
# ('lens1', 'src2') ('lens3', 'src2')
# ('lens1', 'src2') ('lens3', 'src3')
# ('lens1', 'src2') ('lens4', 'src0')
# ('lens1', 'src2') ('lens4', 'src1')
# ('lens1', 'src2') ('lens4', 'src2')
# ('lens1', 'src2') ('lens4', 'src3')
# ('lens1', 'src2') ('src0', 'src0')
# ('lens1', 'src2') ('src0', 'src1')
# ('lens1', 'src2') ('src0', 'src2')
# ('lens1', 'src2') ('src0', 'src3')
# ('lens1', 'src2') ('src1', 'src1')
# ('lens1', 'src2') ('src1', 'src2')
# ('lens1', 'src2') ('src1', 'src3')
# ('lens1', 'src2') ('src2', 'src2')
# ('lens1', 'src2') ('src2', 'src3')
# ('lens1', 'src2') ('src3', 'src3')
# ('lens1', 'src3') ('lens1', 'src3')
# ('lens1', 'src3') ('lens2', 'src0')
# ('lens1', 'src3') ('lens2', 'src1')
# ('lens1', 'src3') ('lens2', 'src2')
# ('lens1', 'src3') ('lens2', 'src3')
# ('lens1', 'src3') ('lens3', 'src0')
# ('lens1', 'src3') ('lens3', 'src1')
# ('lens1', 'src3') ('lens3', 'src2')
# ('lens1', 'src3') ('lens3', 'src3')
# ('lens1', 'src3') ('lens4', 'src0')
# ('lens1', 'src3') ('lens4', 'src1')
# ('lens1', 'src3') ('lens4', 'src2')
# ('lens1', 'src3') ('lens4', 'src3')
# ('lens1', 'src3') ('src0', 'src0')
# ('lens1', 'src3') ('src0', 'src1')
# ('lens1', 'src3') ('src0', 'src2')
# ('lens1', 'src3') ('src0', 'src3')
# ('lens1', 'src3') ('src1', 'src1')
# ('lens1', 'src3') ('src1', 'src2')
# ('lens1', 'src3') ('src1', 'src3')
# ('lens1', 'src3') ('src2', 'src2')
# ('lens1', 'src3') ('src2', 'src3')
# ('lens1', 'src3') ('src3', 'src3')
# ('lens2', 'src0') ('lens2', 'src0')
# ('lens2', 'src0') ('lens2', 'src1')
# ('lens2', 'src0') ('lens2', 'src2')
# ('lens2', 'src0') ('lens2', 'src3')
# ('lens2', 'src0') ('lens3', 'src0')
# ('lens2', 'src0') ('lens3', 'src1')
# ('lens2', 'src0') ('lens3', 'src2')
# ('lens2', 'src0') ('lens3', 'src3')
# ('lens2', 'src0') ('lens4', 'src0')
# ('lens2', 'src0') ('lens4', 'src1')
# ('lens2', 'src0') ('lens4', 'src2')
# ('lens2', 'src0') ('lens4', 'src3')
# ('lens2', 'src0') ('src0', 'src0')
# ('lens2', 'src0') ('src0', 'src1')
# ('lens2', 'src0') ('src0', 'src2')
# ('lens2', 'src0') ('src0', 'src3')
# ('lens2', 'src0') ('src1', 'src1')
# ('lens2', 'src0') ('src1', 'src2')
# ('lens2', 'src0') ('src1', 'src3')
# ('lens2', 'src0') ('src2', 'src2')
# ('lens2', 'src0') ('src2', 'src3')
# ('lens2', 'src0') ('src3', 'src3')
# ('lens2', 'src1') ('lens2', 'src1')
# ('lens2', 'src1') ('lens2', 'src2')
# ('lens2', 'src1') ('lens2', 'src3')
# ('lens2', 'src1') ('lens3', 'src0')
# ('lens2', 'src1') ('lens3', 'src1')
# ('lens2', 'src1') ('lens3', 'src2')
# ('lens2', 'src1') ('lens3', 'src3')
# ('lens2', 'src1') ('lens4', 'src0')
# ('lens2', 'src1') ('lens4', 'src1')
# ('lens2', 'src1') ('lens4', 'src2')
# ('lens2', 'src1') ('lens4', 'src3')
# ('lens2', 'src1') ('src0', 'src0')
# ('lens2', 'src1') ('src0', 'src1')
# ('lens2', 'src1') ('src0', 'src2')
# ('lens2', 'src1') ('src0', 'src3')
# ('lens2', 'src1') ('src1', 'src1')
# ('lens2', 'src1') ('src1', 'src2')
# ('lens2', 'src1') ('src1', 'src3')
# ('lens2', 'src1') ('src2', 'src2')
# ('lens2', 'src1') ('src2', 'src3')
# ('lens2', 'src1') ('src3', 'src3')
# ('lens2', 'src2') ('lens2', 'src2')
# ('lens2', 'src2') ('lens2', 'src3')
# ('lens2', 'src2') ('lens3', 'src0')
# ('lens2', 'src2') ('lens3', 'src1')
# ('lens2', 'src2') ('lens3', 'src2')
# ('lens2', 'src2') ('lens3', 'src3')
# ('lens2', 'src2') ('lens4', 'src0')
# ('lens2', 'src2') ('lens4', 'src1')
# ('lens2', 'src2') ('lens4', 'src2')
# ('lens2', 'src2') ('lens4', 'src3')
# ('lens2', 'src2') ('src0', 'src0')
# ('lens2', 'src2') ('src0', 'src1')
# ('lens2', 'src2') ('src0', 'src2')
# ('lens2', 'src2') ('src0', 'src3')
# ('lens2', 'src2') ('src1', 'src1')
# ('lens2', 'src2') ('src1', 'src2')
# ('lens2', 'src2') ('src1', 'src3')
# ('lens2', 'src2') ('src2', 'src2')
# ('lens2', 'src2') ('src2', 'src3')
# ('lens2', 'src2') ('src3', 'src3')
# ('lens2', 'src3') ('lens2', 'src3')
# ('lens2', 'src3') ('lens3', 'src0')
# ('lens2', 'src3') ('lens3', 'src1')
# ('lens2', 'src3') ('lens3', 'src2')
# ('lens2', 'src3') ('lens3', 'src3')
# ('lens2', 'src3') ('lens4', 'src0')
# ('lens2', 'src3') ('lens4', 'src1')
# ('lens2', 'src3') ('lens4', 'src2')
# ('lens2', 'src3') ('lens4', 'src3')
# ('lens2', 'src3') ('src0', 'src0')
# ('lens2', 'src3') ('src0', 'src1')
# ('lens2', 'src3') ('src0', 'src2')
# ('lens2', 'src3') ('src0', 'src3')
# ('lens2', 'src3') ('src1', 'src1')
# ('lens2', 'src3') ('src1', 'src2')
# ('lens2', 'src3') ('src1', 'src3')
# ('lens2', 'src3') ('src2', 'src2')
# ('lens2', 'src3') ('src2', 'src3')
# ('lens2', 'src3') ('src3', 'src3')
# ('lens3', 'src0') ('lens3', 'src0')
# ('lens3', 'src0') ('lens3', 'src1')
# ('lens3', 'src0') ('lens3', 'src2')
# ('lens3', 'src0') ('lens3', 'src3')
# ('lens3', 'src0') ('lens4', 'src0')
# ('lens3', 'src0') ('lens4', 'src1')
# ('lens3', 'src0') ('lens4', 'src2')
# ('lens3', 'src0') ('lens4', 'src3')
# ('lens3', 'src0') ('src0', 'src0')
# ('lens3', 'src0') ('src0', 'src1')
# ('lens3', 'src0') ('src0', 'src2')
# ('lens3', 'src0') ('src0', 'src3')
# ('lens3', 'src0') ('src1', 'src1')
# ('lens3', 'src0') ('src1', 'src2')
# ('lens3', 'src0') ('src1', 'src3')
# ('lens3', 'src0') ('src2', 'src2')
# ('lens3', 'src0') ('src2', 'src3')
# ('lens3', 'src0') ('src3', 'src3')
# ('lens3', 'src1') ('lens3', 'src1')
# ('lens3', 'src1') ('lens3', 'src2')
# ('lens3', 'src1') ('lens3', 'src3')
# ('lens3', 'src1') ('lens4', 'src0')
# ('lens3', 'src1') ('lens4', 'src1')
# ('lens3', 'src1') ('lens4', 'src2')
# ('lens3', 'src1') ('lens4', 'src3')
# ('lens3', 'src1') ('src0', 'src0')
# ('lens3', 'src1') ('src0', 'src1')
# ('lens3', 'src1') ('src0', 'src2')
# ('lens3', 'src1') ('src0', 'src3')
# ('lens3', 'src1') ('src1', 'src1')
# ('lens3', 'src1') ('src1', 'src2')
# ('lens3', 'src1') ('src1', 'src3')
# ('lens3', 'src1') ('src2', 'src2')
# ('lens3', 'src1') ('src2', 'src3')
# ('lens3', 'src1') ('src3', 'src3')
# ('lens3', 'src2') ('lens3', 'src2')
# ('lens3', 'src2') ('lens3', 'src3')
# ('lens3', 'src2') ('lens4', 'src0')
# ('lens3', 'src2') ('lens4', 'src1')
# ('lens3', 'src2') ('lens4', 'src2')
# ('lens3', 'src2') ('lens4', 'src3')
# ('lens3', 'src2') ('src0', 'src0')
# ('lens3', 'src2') ('src0', 'src1')
# ('lens3', 'src2') ('src0', 'src2')
# ('lens3', 'src2') ('src0', 'src3')
# ('lens3', 'src2') ('src1', 'src1')
# ('lens3', 'src2') ('src1', 'src2')
# ('lens3', 'src2') ('src1', 'src3')
# ('lens3', 'src2') ('src2', 'src2')
# ('lens3', 'src2') ('src2', 'src3')
# ('lens3', 'src2') ('src3', 'src3')
# ('lens3', 'src3') ('lens3', 'src3')
# ('lens3', 'src3') ('lens4', 'src0')
# ('lens3', 'src3') ('lens4', 'src1')
# ('lens3', 'src3') ('lens4', 'src2')
# ('lens3', 'src3') ('lens4', 'src3')
# ('lens3', 'src3') ('src0', 'src0')
# ('lens3', 'src3') ('src0', 'src1')
# ('lens3', 'src3') ('src0', 'src2')
# ('lens3', 'src3') ('src0', 'src3')
# ('lens3', 'src3') ('src1', 'src1')
# ('lens3', 'src3') ('src1', 'src2')
# ('lens3', 'src3') ('src1', 'src3')
# ('lens3', 'src3') ('src2', 'src2')
# ('lens3', 'src3') ('src2', 'src3')
# ('lens3', 'src3') ('src3', 'src3')
# ('lens4', 'src0') ('lens4', 'src0')
# ('lens4', 'src0') ('lens4', 'src1')
# ('lens4', 'src0') ('lens4', 'src2')
# ('lens4', 'src0') ('lens4', 'src3')
# ('lens4', 'src0') ('src0', 'src0')
# ('lens4', 'src0') ('src0', 'src1')
# ('lens4', 'src0') ('src0', 'src2')
# ('lens4', 'src0') ('src0', 'src3')
# ('lens4', 'src0') ('src1', 'src1')
# ('lens4', 'src0') ('src1', 'src2')
# ('lens4', 'src0') ('src1', 'src3')
# ('lens4', 'src0') ('src2', 'src2')
# ('lens4', 'src0') ('src2', 'src3')
# ('lens4', 'src0') ('src3', 'src3')
# ('lens4', 'src1') ('lens4', 'src1')
# ('lens4', 'src1') ('lens4', 'src2')
# ('lens4', 'src1') ('lens4', 'src3')
# ('lens4', 'src1') ('src0', 'src0')
# ('lens4', 'src1') ('src0', 'src1')
# ('lens4', 'src1') ('src0', 'src2')
# ('lens4', 'src1') ('src0', 'src3')
# ('lens4', 'src1') ('src1', 'src1')
# ('lens4', 'src1') ('src1', 'src2')
# ('lens4', 'src1') ('src1', 'src3')
# ('lens4', 'src1') ('src2', 'src2')
# ('lens4', 'src1') ('src2', 'src3')
# ('lens4', 'src1') ('src3', 'src3')
# ('lens4', 'src2') ('lens4', 'src2')
# ('lens4', 'src2') ('lens4', 'src3')
# ('lens4', 'src2') ('src0', 'src0')
# ('lens4', 'src2') ('src0', 'src1')
# ('lens4', 'src2') ('src0', 'src2')
# ('lens4', 'src2') ('src0', 'src3')
# ('lens4', 'src2') ('src1', 'src1')
# ('lens4', 'src2') ('src1', 'src2')
# ('lens4', 'src2') ('src1', 'src3')
# ('lens4', 'src2') ('src2', 'src2')
# ('lens4', 'src2') ('src2', 'src3')
# ('lens4', 'src2') ('src3', 'src3')
# ('lens4', 'src3') ('lens4', 'src3')
# ('lens4', 'src3') ('src0', 'src0')
# ('lens4', 'src3') ('src0', 'src1')
# ('lens4', 'src3') ('src0', 'src2')
# ('lens4', 'src3') ('src0', 'src3')
# ('lens4', 'src3') ('src1', 'src1')
# ('lens4', 'src3') ('src1', 'src2')
# ('lens4', 'src3') ('src1', 'src3')
# ('lens4', 'src3') ('src2', 'src2')
# ('lens4', 'src3') ('src2', 'src3')
# ('lens4', 'src3') ('src3', 'src3')
# ('src0', 'src0') ('src0', 'src0')
# ('src0', 'src0') ('src0', 'src1')
# ('src0', 'src0') ('src0', 'src2')
# ('src0', 'src0') ('src0', 'src3')
# ('src0', 'src0') ('src1', 'src1')
# ('src0', 'src0') ('src1', 'src2')
# ('src0', 'src0') ('src1', 'src3')
# ('src0', 'src0') ('src2', 'src2')
# ('src0', 'src0') ('src2', 'src3')
# ('src0', 'src0') ('src3', 'src3')
# ('src0', 'src1') ('src0', 'src1')
# ('src0', 'src1') ('src0', 'src2')
# ('src0', 'src1') ('src0', 'src3')
# ('src0', 'src1') ('src1', 'src1')
# ('src0', 'src1') ('src1', 'src2')
# ('src0', 'src1') ('src1', 'src3')
# ('src0', 'src1') ('src2', 'src2')
# ('src0', 'src1') ('src2', 'src3')
# ('src0', 'src1') ('src3', 'src3')
# ('src0', 'src2') ('src0', 'src2')
# ('src0', 'src2') ('src0', 'src3')
# ('src0', 'src2') ('src1', 'src1')
# ('src0', 'src2') ('src1', 'src2')
# ('src0', 'src2') ('src1', 'src3')
# ('src0', 'src2') ('src2', 'src2')
# ('src0', 'src2') ('src2', 'src3')
# ('src0', 'src2') ('src3', 'src3')
# ('src0', 'src3') ('src0', 'src3')
# ('src0', 'src3') ('src1', 'src1')
# ('src0', 'src3') ('src1', 'src2')
# ('src0', 'src3') ('src1', 'src3')
# ('src0', 'src3') ('src2', 'src2')
# ('src0', 'src3') ('src2', 'src3')
# ('src0', 'src3') ('src3', 'src3')
# ('src1', 'src1') ('src1', 'src1')
# ('src1', 'src1') ('src1', 'src2')
# ('src1', 'src1') ('src1', 'src3')
# ('src1', 'src1') ('src2', 'src2')
# ('src1', 'src1') ('src2', 'src3')
# ('src1', 'src1') ('src3', 'src3')
# ('src1', 'src2') ('src1', 'src2')
# ('src1', 'src2') ('src1', 'src3')
# ('src1', 'src2') ('src2', 'src2')
# ('src1', 'src2') ('src2', 'src3')
# ('src1', 'src2') ('src3', 'src3')
# ('src1', 'src3') ('src1', 'src3')
# ('src1', 'src3') ('src2', 'src2')
# ('src1', 'src3') ('src2', 'src3')
# ('src1', 'src3') ('src3', 'src3')
# ('src2', 'src2') ('src2', 'src2')
# ('src2', 'src2') ('src2', 'src3')
# ('src2', 'src2') ('src3', 'src3')
# ('src2', 'src3') ('src2', 'src3')
# ('src2', 'src3') ('src3', 'src3')
# ('src3', 'src3') ('src3', 'src3')
# CPU times: user 12min 1s, sys: 440 ms, total: 12min 2s
# Wall time: 58.1 s

# %%
corr = cov2corr(cov)
plt.imshow(corr, vmin=-1, vmax=1, cmap='bwr')
plt.colorbar()

# %% [markdown]
# ## Appendix A: config file content
# Important fields in the configuration file:

# %% [markdown]
# ```yaml
# tjpcov:
#
#   ### This is the place to store your n(z)
#   sacc_file: examples/old_api/des_y1_3x2pt/generic_cl_des_y1_3x2pt_sacc_data.fits
#
#   ### The **cosmology** is from the ccl cosmo object!
#   cosmo: tests/data/cosmo_desy1.yaml
#
#   # Now, tell TJPCov which kind of covariance you want.
#   #   The logic of name is [Space_kind][CovarianceTerm][Options] (case sensitive!)
#   #   as in the example below
#   cov_type: [FourierGaussianFsky]
#
#   ### Survey params:
#   ### a. 5 lens bins ( in arcmin^2)
#   {% for i in range(5) %}
#   Ngal_lens{{ i }}: {{26}} # arc_min^2
#   {% endfor %}
#
#   ### b. 4 source bins
#   {% for i in range(4) %}
#   Ngal_src{{ i }}: {{26}} # arc_min^2
#   {% endfor %}
#
#   ### constant bin sigma_e
#   {% for i in range(4) %}
#   sigma_e_src{{ i }}: {{ 0.26 }}
#   {% endfor %}
#
#   ### linear bias for lenses constant for redshift bin (example notebook)
#   {% for i, val in [(0, 1.5), (1, 1.5), (2, 1.5), (3, 1.5), (4, 1.5)] %}
#   bias_lens{{ i }}: {{ val }}
#   {% endfor %}
#
#   IA: 0.5
#
# ### This is the fraction of sky in your footprint (default=1)
# #       This is ignored by NaMaster case
# GaussianFsky:
#   fsky: 0.3
# ```

# %% [markdown]
# ## Appendix B. Looking the sacc/fits file
# Since TJPCov uses ccl for integrate its power spectra, the n(z) are passed through sacc files.

# %%
from astropy.io import fits

ft = fits.open(f"{homepath}/examples/old_api/des_y1_3x2pt/generic_cl_des_y1_3x2pt_sacc_data.fits")

# %%
f, ax = plt.subplots(2,1, figsize=(7,4), sharex=True)

for trc in [f"tracer:NZ:lens{i}" for i in range(5)]:
    ax[0].plot(ft[trc].data['z'], ft[trc].data['nz'], label=trc)
    
for trc in [f"tracer:NZ:src{i}" for i in range(4)]:
    ax[1].plot(ft[trc].data['z'], ft[trc].data['nz'], label=trc)
    
ax[0].legend(loc='best')
ax[1].legend(loc='best')
[axi.set_xlim(0,2.3) for axi in ax]
# Out:
# [(0.0, 2.3), (0.0, 2.3)]
